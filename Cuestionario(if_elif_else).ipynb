# %% [markdown]
# <a href="https://colab.research.google.com/github/Departamento-TIC/cuestionario-if-elif-else-jacobodominguez2/blob/main/Cuestionario(if_elif_else).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Lab 3: Créate un Cuestionario [Programar Juegos Arcade con Python y Pygame](http://programarcadegames.com/index.php)
#
#
# #Descripción
# Estas son las características que debe tener tu cuestionario:
#
#
# 1.   Créalo con cinco o más preguntas. Puedes preguntar cosas que requieran
# *   un número como respuesta (por ejemplo; ¿Cuánto es 1+1?)
# *   texto (Por ejemplo; ¿Cuál es el apellido de Harry Potter?)
# *   una selección (¿Cuál de estas opciones son las correctas A, B, o C?)
#
# 2.   Si permites que el usuario introduzca respuestas no numéricas, piensa y cubre las distintas formas en que podría contestar. Por ejemplo, si la respuesta es “a”, sería aceptable también “A”? Échale un vistazo a la Sección 3.6 para que recuerdes cómo conseguir esto.
#
# 3. Debes permitir que el usuario sepa que ha acertado con la respuesta correcta. Imprime un mensaje basado en esa respuesta.
# 4. Debes llevar la cuenta del número de respuestas acertadas.
# 5. Al final del programa, deberás mostrar el porcentaje de respuestas contestadas correctamente por el usuario.
#
# #Ejemplo de ejecución
#
# ```
# ¡A jugar!
#
# ¿De cuántos libros consta la serie de Harry Potter? 7
# Correcto!
#
# ¿Cuánto es 3*(2-1)? 3
# Correcto!
#
# ¿Cuánto es 3*2-1? 5
# Correcto!
#
# ¿Quién canta Black Horse and the Cherry Tree?
# 1. Kelly Clarkson
# 2. K.T. Tunstall
# 3. Hillary Duff
# 4. Bon Jovi
# ? 2
# Correcto!
#
# ¿Qué personaje aparece en el billete de un dólar?
# 1. George Washington
# 2. Abraham Lincoln
# 3. John Adams
# 4. Thomas Jefferson
# ? 2
# No.
#
# Mis felicitaciones, has conseguido 4 respuestas correctas!
# Eso es una puntuación del 80 por ciento.
# ```

# %%
print("hola")

# %%
print("¡A jugar!")
#Pregunta 1: Número
respuesta1 = input("/n¿Cuántas copas de Champions tiene el Real Madrid?")
if (respuesta1 == "15"):
  print("correcto!")
  puntos =+1
else:
  print("Incorrecto.")
#Pregunta 2: Texto
respuesta2 = input("/n¿Quién es el actual portero del Real Madrid?")
if (respuesta2 == "Courtois"):
  print("correcto!")
  puntos =+1
else:
  print("Incorrecto, es Courtois")
#Pregunta 3: Operación matemática
respuesta3 = input("/n¿Cuánto es 3*(6-3)? ")
if (respuesta3 == "9"):
  print("correcto!")
  puntos =+1
else:
  print("No, es 9")
#Pregunta 4: Selección múltiple
print("1.Carvajal/n2. 2.Asencio/n3. 3.Mendy/n4. 4.Rodrygo/n5.")
respuesta4 = input("/n¿Quién de aquí no es defensa?")
if (respuesta4 == "4"):
  input("corecto!")
  puntos =+1
else:
  print("Incorrecto, es 4.Rodrygo")
#Pregunta 5: Selección múltiple
print("1.Luis Enrique/n2. 2.Arbeloa/n3. 3.Zidane/n4. 4.Santiago Solari/n5.")
respuesta5 = input("¿Quién de aquí es el actual entrenador del Real Madrid?")
if (respuesta5== "2"):
  print("correcto!")
  puntos =+1
else:
  print("No")
#Cálculos finales
total_preguntas = 5
porcentaje = (puntos/total_preguntas)*100
print("n---RESULTADOS---")
print(f"Enhorabuena!has conseguido {puntos} respuestas correctas")
print("eso es una puntuación del {porcentaje} por ciento")
# Out:
# ¡A jugar!
# /n¿Cuántas copas de Champions tiene el Real Madrid?15
# correcto!
# /n¿Quién es el actual portero del Real Madrid?Courtois
# correcto!
# /n¿Cuánto es 3*(6-3)? 9
# correcto!
# 1.Carvajal/n2. 2.Asencio/n3. 3.Mendy/n4. 4.Rodrygo/n5.
# /n¿Quién de aquí no es defensa?4
# corecto!4
# 1.Luis Enrique/n2. 2.Arbeloa/n3. 3.Zidane/n4. 4.Santiago Solari/n5.
# ¿Quién de aquí es el actual entrenador del Real Madrid?2
# correcto!
# n---RESULTADOS---
# Enhorabuena!has conseguido 1 respuestas correctas
# eso es una puntuación del {porcentaje} por ciento

# %% [markdown]
# # Crea un celda de código debajo y escribe allí tu programa
